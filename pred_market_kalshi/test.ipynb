# %%
from data_fetcher import KalshiSyncIngestor
from spread_fetcher import diagnose_on_discovered_markets

# ing = KalshiSyncIngestor()
# markets = ing.discover_resolved_markets(limit=10)
# tickers = [m["ticker"] for m in markets]
diag = diagnose_on_discovered_markets(n_markets=15)
# Out:
# [diagnose] Querying 9 liquid series directly for settled markets...
#     KXBTCD         -> 100 settled markets
#     KXETHD         -> 100 settled markets
#     KXINXD         -> 0 settled markets
#     KXINX          -> 100 settled markets
#     KXFED          -> 11 settled markets
#     KXCPI          -> 23 settled markets
#     KXHIGHNY       -> 100 settled markets
#     KXNBA          -> 6 settled markets
#     KXNFLGAME      -> 0 settled markets
#
# [diagnose] Selected top 15 by volume_fp (81096819 down to 158584).
#
# [diagnose] trade cutoff = 1779321600 (2026-05-21 00:00:00+00:00); trades newer than this route to the LIVE endpoint, older to /historical.
#
# [diagnose] Pulling trades for 15 markets to assess spread coverage...
